# %%
import pandas as pd

# %%
df=pd.read_excel('C://Users//shesh//OneDrive//bookcustomer.xlsx',header=[0],index_col=0)
df
# Out:
#      Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  Unnamed: 5     Unnamed: 6  \
# NaN          50       Male      Jeans     Clothing          73  Massachusetts
# NaN          21       Male    Sandals     Footwear          90   Rhode Island
# NaN          45       Male     Blouse     Clothing          49         Oregon
# NaN          46       Male   Sneakers     Footwear          20        Wyoming
# NaN          63       Male      Shirt     Clothing          85        Montana
# NaN          27       Male     Shorts     Clothing          34      Louisiana
# NaN          26       Male       Coat    Outerwear          97  West Virginia
# NaN          57       Male    Handbag  Accessories          31       Missouri
# NaN          53       Male      Shoes     Footwear          34       Arkansas
# NaN          30       Male     Shorts     Clothing          68         Hawaii
# NaN          61       Male       Coat    Outerwear          72       Delaware
#
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  Unnamed: 5     Unnamed: 6  \
# 0           50       Male      Jeans     Clothing          73  Massachusetts
# 1           21       Male    Sandals     Footwear          90   Rhode Island
# 2           45       Male     Blouse     Clothing          49         Oregon
# 3           46       Male   Sneakers     Footwear          20        Wyoming
# 4           63       Male      Shirt     Clothing          85        Montana
# 5           27       Male     Shorts     Clothing          34      Louisiana
# 6           26       Male       Coat    Outerwear          97  West Virginia
# 7           57       Male    Handbag  Accessories          31       Missouri
# 8           53       Male      Shoes     Footwear          34       Arkansas
# 9           30       Male     Shorts     Clothing          68         Hawaii
# 10          61       Male       Coat    Outerwear          72       Delaware
#
# ...

# %%
df.columns = ["Age", "Gender", "Product", "Category", "Price", "State", "Size", "Color", "Season", "Rating", "Available"]
df
# Out:
#     Age Gender   Product     Category  Price          State Size      Color  \
# 0    50   Male     Jeans     Clothing     73  Massachusetts    S     Maroon
# 1    21   Male   Sandals     Footwear     90   Rhode Island    M     Maroon
# 2    45   Male    Blouse     Clothing     49         Oregon    M  Turquoise
# 3    46   Male  Sneakers     Footwear     20        Wyoming    M      White
# 4    63   Male     Shirt     Clothing     85        Montana    M       Gray
# 5    27   Male    Shorts     Clothing     34      Louisiana    L   Charcoal
# 6    26   Male      Coat    Outerwear     97  West Virginia    L     Silver
# 7    57   Male   Handbag  Accessories     31       Missouri    M       Pink
# 8    53   Male     Shoes     Footwear     34       Arkansas    L     Purple
# 9    30   Male    Shorts     Clothing     68         Hawaii    S      Olive
# 10   61   Male      Coat    Outerwear     72       Delaware    M       Gold
#
#     Season  Rating Available
# ...

# %%
df['Price']>50
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# Name: Price, dtype: bool

# %%
df[df['Price']>50]
# Out:
#     Age Gender  Product   Category  Price          State Size   Color  Season  \
# 0    50   Male    Jeans   Clothing     73  Massachusetts    S  Maroon  Spring
# 1    21   Male  Sandals   Footwear     90   Rhode Island    M  Maroon  Spring
# 4    63   Male    Shirt   Clothing     85        Montana    M    Gray    Fall
# 6    26   Male     Coat  Outerwear     97  West Virginia    L  Silver  Summer
# 9    30   Male   Shorts   Clothing     68         Hawaii    S   Olive  Winter
# 10   61   Male     Coat  Outerwear     72       Delaware    M    Gold  Winter
#
#     Rating Available
# 0      3.1       Yes
# 1      3.5       Yes
# 4      3.2       Yes
# 6      2.6       Yes
# 9      4.9       Yes
# 10     4.5       Yes

# %%
df[df['Price']>50]
# Out:
#     Age Gender  Product   Category  Price          State Size   Color  Season  \
# 0    50   Male    Jeans   Clothing     73  Massachusetts    S  Maroon  Spring
# 1    21   Male  Sandals   Footwear     90   Rhode Island    M  Maroon  Spring
# 4    63   Male    Shirt   Clothing     85        Montana    M    Gray    Fall
# 6    26   Male     Coat  Outerwear     97  West Virginia    L  Silver  Summer
# 9    30   Male   Shorts   Clothing     68         Hawaii    S   Olive  Winter
# 10   61   Male     Coat  Outerwear     72       Delaware    M    Gold  Winter
#
#     Rating Available
# 0      3.1       Yes
# 1      3.5       Yes
# 4      3.2       Yes
# 6      2.6       Yes
# 9      4.9       Yes
# 10     4.5       Yes

# %%
df[df['Price']>50 & (df['Product']=='Coat')]
df
# Out:
#     Age Gender   Product     Category  Price          State Size      Color  \
# 0    50   Male     Jeans     Clothing     73  Massachusetts    S     Maroon
# 1    21   Male   Sandals     Footwear     90   Rhode Island    M     Maroon
# 2    45   Male    Blouse     Clothing     49         Oregon    M  Turquoise
# 3    46   Male  Sneakers     Footwear     20        Wyoming    M      White
# 4    63   Male     Shirt     Clothing     85        Montana    M       Gray
# 5    27   Male    Shorts     Clothing     34      Louisiana    L   Charcoal
# 6    26   Male      Coat    Outerwear     97  West Virginia    L     Silver
# 7    57   Male   Handbag  Accessories     31       Missouri    M       Pink
# 8    53   Male     Shoes     Footwear     34       Arkansas    L     Purple
# 9    30   Male    Shorts     Clothing     68         Hawaii    S      Olive
# 10   61   Male      Coat    Outerwear     72       Delaware    M       Gold
#
#     Season  Rating Available
# ...

# %%
df[(df['State']!='Hawaii')&(df['State']!='Oregon')]
# Out:
#     Age Gender   Product     Category  Price          State Size     Color  \
# 0    50   Male     Jeans     Clothing     73  Massachusetts    S    Maroon
# 1    21   Male   Sandals     Footwear     90   Rhode Island    M    Maroon
# 3    46   Male  Sneakers     Footwear     20        Wyoming    M     White
# 4    63   Male     Shirt     Clothing     85        Montana    M      Gray
# 5    27   Male    Shorts     Clothing     34      Louisiana    L  Charcoal
# 6    26   Male      Coat    Outerwear     97  West Virginia    L    Silver
# 7    57   Male   Handbag  Accessories     31       Missouri    M      Pink
# 8    53   Male     Shoes     Footwear     34       Arkansas    L    Purple
# 10   61   Male      Coat    Outerwear     72       Delaware    M      Gold
#
#     Season  Rating Available
# 0   Spring     3.1       Yes
# 1   Spring     3.5       Yes
# 3   Summer     2.9       Yes
# 4     Fall     3.2       Yes
# 5   Winter     3.2       Yes
# 6   Summer     2.6       Yes
# ...

# %%
df_filtered = df[~(df['State'] == 'Missouri')]
df_filtered
# Out:
#     Age Gender   Product   Category  Price          State Size      Color  \
# 0    50   Male     Jeans   Clothing     73  Massachusetts    S     Maroon
# 1    21   Male   Sandals   Footwear     90   Rhode Island    M     Maroon
# 2    45   Male    Blouse   Clothing     49         Oregon    M  Turquoise
# 3    46   Male  Sneakers   Footwear     20        Wyoming    M      White
# 4    63   Male     Shirt   Clothing     85        Montana    M       Gray
# 5    27   Male    Shorts   Clothing     34      Louisiana    L   Charcoal
# 6    26   Male      Coat  Outerwear     97  West Virginia    L     Silver
# 8    53   Male     Shoes   Footwear     34       Arkansas    L     Purple
# 9    30   Male    Shorts   Clothing     68         Hawaii    S      Olive
# 10   61   Male      Coat  Outerwear     72       Delaware    M       Gold
#
#     Season  Rating Available
# 0   Spring     3.1       Yes
# 1   Spring     3.5       Yes
# 2   Spring     2.7       Yes
# 3   Summer     2.9       Yes
# ...

# %%
df.query("Price<40 & State!= 'Oregon'")
df
# Out:
#     Age Gender   Product     Category  Price          State Size      Color  \
# 0    50   Male     Jeans     Clothing     73  Massachusetts    S     Maroon
# 1    21   Male   Sandals     Footwear     90   Rhode Island    M     Maroon
# 2    45   Male    Blouse     Clothing     49         Oregon    M  Turquoise
# 3    46   Male  Sneakers     Footwear     20        Wyoming    M      White
# 4    63   Male     Shirt     Clothing     85        Montana    M       Gray
# 5    27   Male    Shorts     Clothing     34      Louisiana    L   Charcoal
# 6    26   Male      Coat    Outerwear     97  West Virginia    L     Silver
# 7    57   Male   Handbag  Accessories     31       Missouri    M       Pink
# 8    53   Male     Shoes     Footwear     34       Arkansas    L     Purple
# 9    30   Male    Shorts     Clothing     68         Hawaii    S      Olive
# 10   61   Male      Coat    Outerwear     72       Delaware    M       Gold
#
#     Season  Rating Available
# ...

# %%
df.query("Category.str.startswith('C')")
df
# Out:
#     Age Gender   Product     Category  Price          State Size      Color  \
# 0    50   Male     Jeans     Clothing     73  Massachusetts    S     Maroon
# 1    21   Male   Sandals     Footwear     90   Rhode Island    M     Maroon
# 2    45   Male    Blouse     Clothing     49         Oregon    M  Turquoise
# 3    46   Male  Sneakers     Footwear     20        Wyoming    M      White
# 4    63   Male     Shirt     Clothing     85        Montana    M       Gray
# 5    27   Male    Shorts     Clothing     34      Louisiana    L   Charcoal
# 6    26   Male      Coat    Outerwear     97  West Virginia    L     Silver
# 7    57   Male   Handbag  Accessories     31       Missouri    M       Pink
# 8    53   Male     Shoes     Footwear     34       Arkansas    L     Purple
# 9    30   Male    Shorts     Clothing     68         Hawaii    S      Olive
# 10   61   Male      Coat    Outerwear     72       Delaware    M       Gold
#
#     Season  Rating Available
# ...

# %%
df.query("Category.str.startswith('C').values")
df
# Out:
#     Age Gender   Product     Category  Price          State Size      Color  \
# 0    50   Male     Jeans     Clothing     73  Massachusetts    S     Maroon
# 1    21   Male   Sandals     Footwear     90   Rhode Island    M     Maroon
# 2    45   Male    Blouse     Clothing     49         Oregon    M  Turquoise
# 3    46   Male  Sneakers     Footwear     20        Wyoming    M      White
# 4    63   Male     Shirt     Clothing     85        Montana    M       Gray
# 5    27   Male    Shorts     Clothing     34      Louisiana    L   Charcoal
# 6    26   Male      Coat    Outerwear     97  West Virginia    L     Silver
# 7    57   Male   Handbag  Accessories     31       Missouri    M       Pink
# 8    53   Male     Shoes     Footwear     34       Arkansas    L     Purple
# 9    30   Male    Shorts     Clothing     68         Hawaii    S      Olive
# 10   61   Male      Coat    Outerwear     72       Delaware    M       Gold
#
#     Season  Rating Available
# ...

# %%
df_filtered = df.loc[df['Category'].str.startswith('C')]
df_filtered
# Out:
#    Age Gender Product  Category  Price          State Size      Color  Season  \
# 0   50   Male   Jeans  Clothing     73  Massachusetts    S     Maroon  Spring
# 2   45   Male  Blouse  Clothing     49         Oregon    M  Turquoise  Spring
# 4   63   Male   Shirt  Clothing     85        Montana    M       Gray    Fall
# 5   27   Male  Shorts  Clothing     34      Louisiana    L   Charcoal  Winter
# 9   30   Male  Shorts  Clothing     68         Hawaii    S      Olive  Winter
#
#    Rating Available
# 0     3.1       Yes
# 2     2.7       Yes
# 4     3.2       Yes
# 5     3.2       Yes
# 9     4.9       Yes

# %%
df_filtered = df.loc[df['Category'].str.startswith('C'), ['Gender', 'Size', 'Color']]
df_filtered
# Out:
#   Gender Size      Color
# 0   Male    S     Maroon
# 2   Male    M  Turquoise
# 4   Male    M       Gray
# 5   Male    L   Charcoal
# 9   Male    S      Olive

# %%
prd=['Jeans','Shirt','Coat']

# %%
df1=df[df.Product.isin(prd)]
df1
# Out:
#     Age Gender Product   Category  Price          State Size   Color  Season  \
# 0    50   Male   Jeans   Clothing     73  Massachusetts    S  Maroon  Spring
# 4    63   Male   Shirt   Clothing     85        Montana    M    Gray    Fall
# 6    26   Male    Coat  Outerwear     97  West Virginia    L  Silver  Summer
# 10   61   Male    Coat  Outerwear     72       Delaware    M    Gold  Winter
#
#     Rating Available
# 0      3.1       Yes
# 4      3.2       Yes
# 6      2.6       Yes
# 10     4.5       Yes

# %%
df1=df[~df.Product.isin(prd)]
df1
# Out:
#    Age Gender   Product     Category  Price         State Size      Color  \
# 1   21   Male   Sandals     Footwear     90  Rhode Island    M     Maroon
# 2   45   Male    Blouse     Clothing     49        Oregon    M  Turquoise
# 3   46   Male  Sneakers     Footwear     20       Wyoming    M      White
# 5   27   Male    Shorts     Clothing     34     Louisiana    L   Charcoal
# 7   57   Male   Handbag  Accessories     31      Missouri    M       Pink
# 8   53   Male     Shoes     Footwear     34      Arkansas    L     Purple
# 9   30   Male    Shorts     Clothing     68        Hawaii    S      Olive
#
#    Season  Rating Available
# 1  Spring     3.5       Yes
# 2  Spring     2.7       Yes
# 3  Summer     2.9       Yes
# 5  Winter     3.2       Yes
# 7  Spring     4.8       Yes
# 8    Fall     4.1       Yes
# 9  Winter     4.9       Yes

# %%
df.loc[df.Size=='M',['Color','Season']]
# Out:
#         Color  Season
# 1      Maroon  Spring
# 2   Turquoise  Spring
# 3       White  Summer
# 4        Gray    Fall
# 7        Pink  Spring
# 10       Gold  Winter

# %%
df.loc[(df.Size=='M') & (df.Rating >3),['Color','Season'] ]
# Out:
#      Color  Season
# 1   Maroon  Spring
# 4     Gray    Fall
# 7     Pink  Spring
# 10    Gold  Winter

# %%
df.nlargest(4,'Rating')
# Out:
#     Age Gender  Product     Category  Price     State Size   Color  Season  \
# 9    30   Male   Shorts     Clothing     68    Hawaii    S   Olive  Winter
# 7    57   Male  Handbag  Accessories     31  Missouri    M    Pink  Spring
# 10   61   Male     Coat    Outerwear     72  Delaware    M    Gold  Winter
# 8    53   Male    Shoes     Footwear     34  Arkansas    L  Purple    Fall
#
#     Rating Available
# 9      4.9       Yes
# 7      4.8       Yes
# 10     4.5       Yes
# 8      4.1       Yes

# %%
df.nsmallest(4,'Rating')
# Out:
#    Age Gender   Product   Category  Price          State Size      Color  \
# 6   26   Male      Coat  Outerwear     97  West Virginia    L     Silver
# 2   45   Male    Blouse   Clothing     49         Oregon    M  Turquoise
# 3   46   Male  Sneakers   Footwear     20        Wyoming    M      White
# 0   50   Male     Jeans   Clothing     73  Massachusetts    S     Maroon
#
#    Season  Rating Available
# 6  Summer     2.6       Yes
# 2  Spring     2.7       Yes
# 3  Summer     2.9       Yes
# 0  Spring     3.1       Yes

# %%
df[df.apply(lambda x: x['Size']=='M' and x['Season']=='Summer',axis=1)]
# Out:
#    Age Gender   Product  Category  Price    State Size  Color  Season  Rating  \
# 3   46   Male  Sneakers  Footwear     20  Wyoming    M  White  Summer     2.9
#
#   Available
# 3       Yes

# %%
df[df.apply(lambda x: x['Size'] == 'M' and x['Season'] == 'Summer', axis=1)]
# Out:
#    Age Gender   Product  Category  Price    State Size  Color  Season  Rating  \
# 3   46   Male  Sneakers  Footwear     20  Wyoming    M  White  Summer     2.9
#
#   Available
# 3       Yes
