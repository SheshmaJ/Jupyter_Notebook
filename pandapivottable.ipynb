# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\shesh\\OneDrive\\Desktop\\shopping_trends.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
pivot = pd.pivot_table(df, index=['Payment Method'],values=['Previous Purchases','Review Rating'])
pivot
# Out:
#                 Previous Purchases  Review Rating
# Payment Method
# Bank Transfer            26.164557       3.775633
# Cash                     25.060185       3.743364
# Credit Card              24.389368       3.738937
# Debit Card               25.184834       3.723539
# PayPal                   25.504702       3.760815
# Venmo                    25.891271       3.758346

# %%
import numpy as np

# %%
pivot = pd.pivot_table(df, index=['Payment Method'],values=['Previous Purchases','Review Rating'],aggfunc=np.sum)
pivot
# Out:
# C:\Users\shesh\AppData\Local\Temp\ipykernel_16256\4171889928.py:1: FutureWarning: The provided callable <function sum at 0x00000262C1A3E7A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot = pd.pivot_table(df, index=['Payment Method'],values=['Previous Purchases','Review Rating'],aggfunc=np.sum)
#                 Previous Purchases  Review Rating
# Payment Method
# Bank Transfer                16536         2386.2
# Cash                         16239         2425.7
# Credit Card                  16975         2602.3
# Debit Card                   15942         2357.0
# PayPal                       16272         2399.4
# Venmo                        16907         2454.2

# %%
pivot = pd.pivot_table(df, index=['Payment Method','Category'],values=['Previous Purchases','Review Rating'],aggfunc={'Previous Purchases':np.sum,'Review Rating':np.mean})
pivot
# Out:
# C:\Users\shesh\AppData\Local\Temp\ipykernel_16256\3514853249.py:1: FutureWarning: The provided callable <function sum at 0x00000262C1A3E7A0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot = pd.pivot_table(df, index=['Payment Method','Category'],values=['Previous Purchases','Review Rating'],aggfunc={'Previous Purchases':np.sum,'Review Rating':np.mean})
# C:\Users\shesh\AppData\Local\Temp\ipykernel_16256\3514853249.py:1: FutureWarning: The provided callable <function mean at 0x00000262C1A3F880> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot = pd.pivot_table(df, index=['Payment Method','Category'],values=['Previous Purchases','Review Rating'],aggfunc={'Previous Purchases':np.sum,'Review Rating':np.mean})
# ...

# %%
pivot.plot()
# Out:
# <Axes: xlabel='Payment Method,Category'>

# %%
pivot.plot(kind='bar',title='purchase vs review')
# Out:
# <Axes: title={'center': 'purchase vs review'}, xlabel='Payment Method,Category'>

# %%
import matplotlib.pyplot as plt

# %%
weather_data={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temp':[32,35,36,37,32,35],
    'event':['rain','sunny','snow','rain','sunny','rain']
}
df=pd.DataFrame(weather_data)
df
# Out:
#         day  temp  event
# 0  1/1/2017    32   rain
# 1  1/2/2017    35  sunny
# 2  1/3/2017    36   snow
# 3  1/4/2017    37   rain
# 4  1/5/2017    32  sunny
# 5  1/6/2017    35   rain

# %%
df.plot(kind='bar')
plt.show()
