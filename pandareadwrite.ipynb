# %%
import pandas as pd, os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shesh'

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.bash_history', '.cache', '.conda', '.condarc', '.config', '.continuum', '.eclipse', '.git', '.gitconfig', '.idea', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jenkins', '.jupyter', '.m2', '.matplotlib', '.ms-ad', '.openjfx', '.p2', '.python_history', '.soapuios', '.ssh', '.tooling', '3D Objects', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'default-soapui-workspace.xml', 'Downloads', 'eclipse-workspace', 'edb_npgsql.exe', 'edb_pgagent_pg17.exe', 'edb_pgbouncer.exe', 'Favorites', 'git', 'learningplace', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'pandabasics.ipynb', 'postgresql_12
# ...

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\shesh\\OneDrive\\Desktop\\shopping_trends.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
df = pd.read_csv("C:\\Users\\shesh\\OneDrive\\Desktop\\shopping_trends.csv",header=None,skiprows=3)
df
# Out:
#         0   1       2         3            4   5              6  7   \
# 0        3  50    Male     Jeans     Clothing  73  Massachusetts  S
# 1        4  21    Male   Sandals     Footwear  90   Rhode Island  M
# 2        5  45    Male    Blouse     Clothing  49         Oregon  M
# 3        6  46    Male  Sneakers     Footwear  20        Wyoming  M
# 4        7  63    Male     Shirt     Clothing  85        Montana  M
# ...    ...  ..     ...       ...          ...  ..            ... ..
# 3893  3896  40  Female    Hoodie     Clothing  28       Virginia  L
# 3894  3897  52  Female  Backpack  Accessories  49           Iowa  L
# 3895  3898  46  Female      Belt  Accessories  33     New Jersey  L
# 3896  3899  44  Female     Shoes     Footwear  77      Minnesota  S
# 3897  3900  52  Female   Handbag  Accessories  81     California  M
#
#              8       9    10   11             12              13   14   15  \
# ...

# %% [markdown]
# df = pd.read_csv("C:\\Users\\shesh\\OneDrive\\Desktop\\shopping_trends.csv",nrows=7)
# df

# %%
#USING Converters

# %%
def convert_Category_cell(cell):
    if cell=='Clothing':
        return 'Cloth'
        return cell

# %%
df = pd.read_csv("C:\\Users\\shesh\\OneDrive\\Desktop\\shopping_trends.csv",converters={'Category':convert_Category_cell})
df
# Out:
#       Customer ID  Age  Gender Item Purchased Category  Purchase Amount (USD)  \
# 0               1   55    Male         Blouse    Cloth                     53
# 1               2   19    Male        Sweater    Cloth                     64
# 2               3   50    Male          Jeans    Cloth                     73
# 3               4   21    Male        Sandals     None                     90
# 4               5   45    Male         Blouse    Cloth                     49
# ...           ...  ...     ...            ...      ...                    ...
# 3895         3896   40  Female         Hoodie    Cloth                     28
# 3896         3897   52  Female       Backpack     None                     49
# 3897         3898   46  Female           Belt     None                     33
# 3898         3899   44  Female          Shoes     None                     77
# 3899         3900   52  Female        Handbag     None                     81
#
# ...

# %%
df = pd.read_csv("C:\\Users\\shesh\\OneDrive\\Desktop\\shopping_trends.csv",na_values={'Category':["None",'n.a.']})
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df = pd.read_excel("C:\\Users\\shesh\\OneDrive\\Desktop\\Demo1.xlsx")
df
# Out:
#         Unnamed: 0                        Unnamed: 1             Unnamed: 2  \
# 0             Name                               NaN                  Email
# 1  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 2     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 3    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 4              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 5              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 6      Matt Ashley                      Maya Randall              Analytics
# 7   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 8    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 9       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                      Unnamed: 3
# 0                        Course
# 1  Wednesday, December 14, 2022
# 2     Friday, December 30, 2022
# ...

# %%
df = pd.read_excel("C:\\Users\\shesh\\OneDrive\\Desktop\\Demo1.xlsx",header=None)
df
# Out:
#                   0                                 1                      2  \
# 0               NaN                               NaN                    NaN
# 1              Name                               NaN                  Email
# 2   Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 3      Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 4     Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 5               NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 6               NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 7       Matt Ashley                      Maya Randall              Analytics
# 8    Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 9     Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 10       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                                3
# ...

# %%
df = pd.read_excel("C:\\Users\\shesh\\OneDrive\\Desktop\\Demo1.xlsx",header=1)
df
# Out:
#               Name                        Unnamed: 1                  Email  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                          Course
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
df.columns = ["Name", "Email", "Course", "Date"]
df
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
new_df=df.fillna('abc')
new_df
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              abc        Ramon_Redden905@1kmd3.club  Design and technology
# 4              abc       Maya_Randall2939@lhp4j.meet                    abc
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           abc
# ...

# %%
new_df=df.fillna({'Course':'analytics','Date':'no event'})
new_df
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet              analytics
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                      no event
# ...

# %%
new_df=df.drop([1,3,5],axis=0)
new_df                                                       #delete rowbased on index
# Out:
#               Name                 Course                          Date
# 0  Hailey Antcliff             Leadership  Wednesday, December 14, 2022
# 2    Carina Stubbs             Accounting      Sunday, December 4, 2022
# 4              NaN                    NaN                           NaN
# 6   Freya Reynolds             Accounting    Saturday, December 3, 2022
# 7    Ronald Newton  Design and technology   Thursday, December 22, 2022
# 8       Jack Hobbs  Design and technology   Wednesday, December 7, 2022

# %%
new_df.reset_index(inplace=True)
new_df                                                                         #reset the index deteled
# Out:
#    level_0  index             Name                 Course  \
# 0        0      0  Hailey Antcliff             Leadership
# 1        1      2    Carina Stubbs             Accounting
# 2        2      4              NaN                    NaN
# 3        3      6   Freya Reynolds             Accounting
# 4        4      7    Ronald Newton  Design and technology
# 5        5      8       Jack Hobbs  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1      Sunday, December 4, 2022
# 2                           NaN
# 3    Saturday, December 3, 2022
# 4   Thursday, December 22, 2022
# 5   Wednesday, December 7, 2022

# %%
new_df.head()
# Out:
#                                 Course                          Date
# Name
# Hailey Antcliff             Leadership  Wednesday, December 14, 2022
# Carina Stubbs               Accounting      Sunday, December 4, 2022
# NaN                                NaN                           NaN
# Freya Reynolds              Accounting    Saturday, December 3, 2022
# Ronald Newton    Design and technology   Thursday, December 22, 2022

# %%
df = pd.read_excel("C:\\Users\\shesh\\OneDrive\\Desktop\\Demo1.xlsx",header=1)
df
# Out:
#               Name                        Unnamed: 1                  Email  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                          Course
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
df=df.replace({'Leadership':'Managememt'})
df
# Out:
#               Name                        Unnamed: 1                  Email  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Managememt
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                          Course
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
df=df.groupby('Email')
df

# %%
for Email,Email_df in df:
    print(Email)
    print(Email_df)
# Out:
# Accounting
#              Name                     Unnamed: 1       Email  \
# 2   Carina Stubbs    Carina_Stubbs8509@jh02o.org  Accounting
# 6  Freya Reynolds  Freya_Reynolds9608@bqkv0.site  Accounting
#
#                        Course
# 2    Sunday, December 4, 2022
# 6  Saturday, December 3, 2022
# Analytics
#            Name                        Unnamed: 1      Email  \
# 1  Harvey Reyes  Harvey_Reyes9354@voylg.directory  Analytics
# 5   Matt Ashley                      Maya Randall  Analytics
#
#                       Course
# 1  Friday, December 30, 2022
# 5  Friday, December 30, 2022
# Design and technology
#             Name                    Unnamed: 1                  Email  \
# 3            NaN    Ramon_Redden905@1kmd3.club  Design and technology
# 7  Ronald Newton   Ronald_Newton1403@1kmd3.com  Design and technology
# 8     Jack Hobbs  Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                         Course
# 3  Wednesday, December 7, 2022
# ...

# %%
df.get_group('Analytics')
# Out:
#            Name                        Unnamed: 1      Email  \
# 1  Harvey Reyes  Harvey_Reyes9354@voylg.directory  Analytics
# 5   Matt Ashley                      Maya Randall  Analytics
#
#                       Course
# 1  Friday, December 30, 2022
# 5  Friday, December 30, 2022

# %%
df = pd.read_excel("C:\\Users\\shesh\\OneDrive\\Desktop\\Demo1.xlsx",header=None)
df
df.columns = ["Name", "Email", "Course", "Date"]
df
df = df.drop([0, 1]).reset_index(drop=True)
df
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
df1=pd.melt(df,id_vars=['Email'])
df1                                                                                 #Melt
# Out:
#                                Email variable                         value
# 0    Hailey_Antcliff9757@yahoo.audio     Name               Hailey Antcliff
# 1   Harvey_Reyes9354@voylg.directory     Name                  Harvey Reyes
# 2        Carina_Stubbs8509@jh02o.org     Name                 Carina Stubbs
# 3         Ramon_Redden905@1kmd3.club     Name                           NaN
# 4        Maya_Randall2939@lhp4j.meet     Name                           NaN
# 5                       Maya Randall     Name                   Matt Ashley
# 6      Freya_Reynolds9608@bqkv0.site     Name                Freya Reynolds
# 7        Ronald_Newton1403@1kmd3.com     Name                 Ronald Newton
# 8       Jack_Hobbs4073@evyvh.auction     Name                    Jack Hobbs
# 9    Hailey_Antcliff9757@yahoo.audio   Course                    Leadership
# 10  Harvey_Reyes9354@voylg.directory   Course                     Analytics
# ...

# %%
df1[df1['variable'] == 'Date']
# Out:
#                                Email variable                         value
# 18   Hailey_Antcliff9757@yahoo.audio     Date  Wednesday, December 14, 2022
# 19  Harvey_Reyes9354@voylg.directory     Date     Friday, December 30, 2022
# 20       Carina_Stubbs8509@jh02o.org     Date      Sunday, December 4, 2022
# 21        Ramon_Redden905@1kmd3.club     Date   Wednesday, December 7, 2022
# 22       Maya_Randall2939@lhp4j.meet     Date                           NaN
# 23                      Maya Randall     Date     Friday, December 30, 2022
# 24     Freya_Reynolds9608@bqkv0.site     Date    Saturday, December 3, 2022
# 25       Ronald_Newton1403@1kmd3.com     Date   Thursday, December 22, 2022
# 26      Jack_Hobbs4073@evyvh.auction     Date   Wednesday, December 7, 2022
