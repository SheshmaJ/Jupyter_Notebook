# %%
import pandas as pd
import numpy as np

# %%
data=np.array([1,3,np.nan,5,6])
data
# Out:
# array([ 1.,  3., nan,  5.,  6.])

# %%
np.nansum(data)
# Out:
# 15.0

# %%
np.nanmean(data)
# Out:
# 3.75

# %%
a=pd.Series([2,5,np.nan,'python',None,15,3]).isnull()
a
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
a.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# dtype: bool

# %%
a[~a.notnull()]
# Out:
# Series([], dtype: bool)

# %%
order=pd.read_csv("C://Users//shesh//OneDrive//Desktop//unbill_data.csv")
order
# Out:
#                 Segment                 Billing_Class   Site_Billing_Status  \
# 0                Others  Small and Medium Enterprises  Live - Billed & Stop
# 1                Others  Small and Medium Enterprises  Live - Billed & Stop
# 2                Others  Small and Medium Enterprises  Live - Billed & Stop
# 3                Others  Small and Medium Enterprises  Live - Billed & Stop
# 4                Others  Small and Medium Enterprises  Live - Billed & Stop
# ...                 ...                           ...                   ...
# 39995            Others  Small and Medium Enterprises  Live - Billed & Stop
# 39996  Small Enterprise  Small and Medium Enterprises  Live - Billed & Stop
# 39997            Others  Small and Medium Enterprises  Live - Billed & Stop
# 39998            Others  Small and Medium Enterprises  Live - Billed & Stop
# 39999            Others  Small and Medium Enterprises  Live - Billed & Stop
#
# ...

# %%
order.isnull()
# Out:
#        Segment  Billing_Class  Site_Billing_Status  Site_Status  Consumption  \
# 0        False          False                False        False        False
# 1        False          False                False        False        False
# 2        False          False                False        False        False
# 3        False          False                False        False        False
# 4        False          False                False        False        False
# ...        ...            ...                  ...          ...          ...
# 39995    False          False                False        False        False
# 39996    False          False                False        False        False
# 39997    False          False                False        False        False
# 39998    False          False                False        False        False
# 39999    False          False                False        False        False
#
# ...

# %%
order.isnull().sum()
# Out:
# Segment                    0
# Billing_Class              0
# Site_Billing_Status        0
# Site_Status                0
# Consumption                0
# Value_Unbilled             0
# Billing_Frequency          0
# UnbilledDays             337
# RootCause                  0
# Voice_Attempt          38945
# target                     0
# dtype: int64

# %%
order.isnull().sum()/len(order)*100
# Out:
# Segment                 0.0000
# Billing_Class           0.0000
# Site_Billing_Status     0.0000
# Site_Status             0.0000
# Consumption             0.0000
# Value_Unbilled          0.0000
# Billing_Frequency       0.0000
# UnbilledDays            0.8425
# RootCause               0.0000
# Voice_Attempt          97.3625
# target                  0.0000
# dtype: float64

# %%
order.dropna(axis='columns')
# Out:
#                 Segment                 Billing_Class   Site_Billing_Status  \
# 0                Others  Small and Medium Enterprises  Live - Billed & Stop
# 1                Others  Small and Medium Enterprises  Live - Billed & Stop
# 2                Others  Small and Medium Enterprises  Live - Billed & Stop
# 3                Others  Small and Medium Enterprises  Live - Billed & Stop
# 4                Others  Small and Medium Enterprises  Live - Billed & Stop
# ...                 ...                           ...                   ...
# 39995            Others  Small and Medium Enterprises  Live - Billed & Stop
# 39996  Small Enterprise  Small and Medium Enterprises  Live - Billed & Stop
# 39997            Others  Small and Medium Enterprises  Live - Billed & Stop
# 39998            Others  Small and Medium Enterprises  Live - Billed & Stop
# 39999            Others  Small and Medium Enterprises  Live - Billed & Stop
#
# ...

# %%
data = {'A': [1, 2, np.nan], 
        'B': [4, 5, 6], 
        'C': [7, np.nan, 9]}

# %%
df=pd.DataFrame(data)
df
# Out:
#      A  B    C
# 0  1.0  4  7.0
# 1  2.0  5  NaN
# 2  NaN  6  9.0

# %%
df.dropna(axis='columns',thresh=3)
# Out:
#    B
# 0  4
# 1  5
# 2  6

# %%
df.dropna(axis='rows',thresh=3)
# Out:
#      A  B    C
# 0  1.0  4  7.0

# %%
df.fillna(0)
# Out:
#      A  B    C
# 0  1.0  4  7.0
# 1  2.0  5  0.0
# 2  0.0  6  9.0

# %%
df.fillna(method='ffill',axis='columns')
# Out:
# C:\Users\shesh\AppData\Local\Temp\ipykernel_12344\1140326825.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',axis='columns')
#      A    B    C
# 0  1.0  4.0  7.0
# 1  2.0  5.0  5.0
# 2  NaN  6.0  9.0
