# %%
import pandas as pd

# %%
df=pd.read_excel("C://Users//shesh//OneDrive//Desktop//Demo1.xlsx",header=1)
df
# Out:
#               Name                        Unnamed: 1                  Email  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                          Course
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns = ['Name', 'Email', 'Course', 'Date']
df
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                           NaN
# ...

# %%
df.fillna('not available')
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3    not available        Ramon_Redden905@1kmd3.club  Design and technology
# 4    not available       Maya_Randall2939@lhp4j.meet          not available
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date
# 0  Wednesday, December 14, 2022
# 1     Friday, December 30, 2022
# 2      Sunday, December 4, 2022
# 3   Wednesday, December 7, 2022
# 4                 not available
# ...

# %%
df['Course _name_upper']=df['Course'].fillna(" ").apply(lambda name: name.upper())
df
# Out:
#               Name                             Email                 Course  \
# 0  Hailey Antcliff   Hailey_Antcliff9757@yahoo.audio             Leadership
# 1     Harvey Reyes  Harvey_Reyes9354@voylg.directory              Analytics
# 2    Carina Stubbs       Carina_Stubbs8509@jh02o.org             Accounting
# 3              NaN        Ramon_Redden905@1kmd3.club  Design and technology
# 4              NaN       Maya_Randall2939@lhp4j.meet                    NaN
# 5      Matt Ashley                      Maya Randall              Analytics
# 6   Freya Reynolds     Freya_Reynolds9608@bqkv0.site             Accounting
# 7    Ronald Newton       Ronald_Newton1403@1kmd3.com  Design and technology
# 8       Jack Hobbs      Jack_Hobbs4073@evyvh.auction  Design and technology
#
#                            Date     Course _name_upper
# 0  Wednesday, December 14, 2022             LEADERSHIP
# 1     Friday, December 30, 2022              ANALYTICS
# ...
